# %%
class dualSVM:
    def __init__(self, C=1.0, kernel="rbf", gamma=1.0, degree=3, coef0=1.0,
                 n_iters=500, lr=0.001, tol=1e-4, random_state=42):
        self.C = C
        self.kernel = kernel
        self.gamma = gamma
        self.degree = degree
        self.coef0 = coef0
        self.n_iters = n_iters
        self.lr = lr
        self.tol = tol
        self.random_state = random_state

        self.alpha_ = None
        self.b_ = None
        self.X_train_ = None
        self.y_train_ = None
